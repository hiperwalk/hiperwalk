# %% [markdown]
# ## Grover's algorithm as a coined QW on the complete graph

# %%
# !echo $USER, $HOSTNAME
# !date
# !export OMP_NUM_THREADS=3
# Out:
# bidu, pc013047
# Wed Nov 19 11:47:06 -03 2025

# %%
# !echo OMP_NUM_THREADS=$OMP_NUM_THREADS
import numpy as np
import networkx as nx
import hiperwalk as hpw
myHPC_option=None
myHPC_option="cpu"
import os
os.environ["OMP_NUM_THREADS"] = "2" 

hpw.set_hpc(myHPC_option)
# Out:
# OMP_NUM_THREADS=3
# BD, em def set_hpc(hpc), hpc= cpu
# lib_name = /home/bidu/hiperblas/lib/libhiperblas-cpu-bridge.so
# BD, em ./pyhiperblas/hiperblas_wrapper.c: static PyObject* py_init_engine, lib_name =/home/bidu/hiperblas/lib/libhiperblas-cpu-bridge.so
# em src/libhiperblas.c: void load_plugin(bridge_manager_t *manager, char* library_name, int index) {
# so bridge library name: /home/bidu/hiperblas/lib/libhiperblas-cpu-bridge.so,

# %% [markdown]
# #### Defining an instance of the complete graph with loops using NetworkX

# %%
N = 100
K_N = nx.complete_graph(N)
A = nx.adjacency_matrix(K_N)+np.eye(N)
graph = hpw.Graph(A)

# %% [markdown]
# #### Creating an instance of a coined QW

# %%
import os
os.environ["OMP_NUM_THREADS"] = "2" 
qw = hpw.Coined(graph, shift='flipflop', coin='G', marked={'-G': [0]})
# Out:
# em coined.py, __init__
# _set_shift     :   Tempo decorrido: 0.192684 segundos
# _set_coin      :   Tempo decorrido: 0.000017 segundos
# _set_marked    :   Tempo decorrido: 0.000033 segundos
# BD, em hiperwalk/quantum_walk/coined.py: def _set_evolution
# BD, em _set_evolution, CALL  C = self.get_coin(), monta a matriz CSR
# ++++++  em hiperwalk/quantum_walk/coined.py: get_coin(self)
# em get_coin: self._coin= ['grover', 'grover', 'grover', 'grover', 'grover']
# em get_coin: scipy.sparse.issparse(self._coin) = False
# em get_coin(self), semi-final
# coin_list[:5]= ['minus_grover', 'grover', 'grover', 'grover', 'grover']
# em def _coin_list_to_explicit_coin, blocks[0].dtype= float64
# type(S.indices)   =  <class 'numpy.ndarray'>
# S.indices.dtype   =  int64
# indices contiguous:  True
# S.indptr.dtype    =  int64
# indptr contiguous :  True
# type(S)           =  <class 'scipy.sparse._csr.csr_array'>
# S.dtype           =  int8
# S.data.dtype      =  int8
# data contiguous   :  True
# type(C.indices)   =  <class 'numpy.ndarray'>
# C.indices.dtype   =  int64
# indices contiguous:  True
# C.indptr.dtype    =  int64
# indptr contiguous :  True
# type(C)           =  <class 'scipy.sparse._csr.csr_array'>
# C.dtype           =  float64
# C.data.dtype      =  float64
# data contiguous   :  True
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def send_matrix(M)
# BD, M.dtype= int8 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def _send_sparse_matrix(M)
# M.dtype= int8 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, is_complex=False
# BD, hiperblas.COMPLEX=3
# BD, hiperblas.FLOAT=2
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def send_matrix(M)
# BD, M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def _send_sparse_matrix(M)
# M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, is_complex=False
# BD, hiperblas.COMPLEX=3
# BD, hiperblas.FLOAT=2
# BD, em pyhiperblas/hiperblas_wrapper.c: py_sparse_matrix_new( PyObject* self, PyObject* args)
#  call bridge_manager.bridges[bridge_index].smatrix_new(rows, cols, data_type);
# BD, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c, smatrix_new
#  before CALL PyObject* po = PyCapsule_New((void*)a, py_sparse_matrix_new, py_sparse_matrix_delete
# em py_sparse_matrix_new FINAL 0x7fc41d99de30
# → Entrou em py_smatrixConnect()
# data_type = 2, T_FLOAT = 2, T_COMPLEX = 3
# CSR conectado: nrow=10000, ncol=10000, nnz=10000
# em hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatreqdev(smatrix_t *m) {
#  m->location = 0, LOCDEV = 128
#    m->row_ptr   = 0x2211e540
#    m->col_idx   = 0x22163f40
#    m->values    = 0x2214f2b0
#    m->idxColMem = (nil)
#    m->extra     = (nil)
# em smatreqdev, ANTES DO fim
#  m->location  = 128, LOCDEV = 128
#  nao coloque NULL.  m->col_idx   = 0x22163f40
#    m->idxColMem = 0x22163f40
#  nao coloque NULL.  m->values = 0x2214f2b0
#    m->extra  = 0x2214f2b0
# BD, em pyhiperblas/hiperblas_wrapper.c: py_sparse_matrix_new( PyObject* self, PyObject* args)
#  call bridge_manager.bridges[bridge_index].smatrix_new(rows, cols, data_type);
# BD, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c, smatrix_new
#  before CALL PyObject* po = PyCapsule_New((void*)a, py_sparse_matrix_new, py_sparse_matrix_delete
# em py_sparse_matrix_new FINAL 0x7fc41d99db60
# → Entrou em py_smatrixConnect()
# data_type = 2, T_FLOAT = 2, T_COMPLEX = 3
# CSR conectado: nrow=10000, ncol=10000, nnz=1000000
# em hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatreqdev(smatrix_t *m) {
#  m->location = 0, LOCDEV = 128
#    m->row_ptr   = 0x230a6990
#    m->col_idx   = 0x22905780
#    m->values    = 0x7fc41bd0b010
#    m->idxColMem = (nil)
#    m->extra     = (nil)
# em smatreqdev, ANTES DO fim
#  m->location  = 128, LOCDEV = 128
#  nao coloque NULL.  m->col_idx   = 0x22905780
#    m->idxColMem = 0x22905780
#  nao coloque NULL.  m->values = 0x7fc41bd0b010
#    m->extra  = 0x7fc41bd0b010
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def send_matrix(M)
# BD, M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def _send_sparse_matrix(M)
# M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, is_complex=False
# BD, hiperblas.COMPLEX=3
# BD, hiperblas.FLOAT=2
# BD1, em _pyHiperblas_interface.py: def permute_sparse_matrix(nbl_smatS, nbl_smatC, nbl_smatU):
# BD, em _set_evolution, RETURN
# _set_evolution :   Tempo decorrido: 0.075576 segundos
# BD, em hiperwalk/quantum_walk/coined.py, FINAL  def __init__(self, graph=None, **kwargs):
# BD, em pyhiperblas/hiperblas_wrapper.c: py_sparse_matrix_new( PyObject* self, PyObject* args)
#  call bridge_manager.bridges[bridge_index].smatrix_new(rows, cols, data_type);
# BD, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c, smatrix_new
#  before CALL PyObject* po = PyCapsule_New((void*)a, py_sparse_matrix_new, py_sparse_matrix_delete
# em py_sparse_matrix_new FINAL 0x7fc41d99dfe0
# → Entrou em py_smatrixConnect()
# data_type = 2, T_FLOAT = 2, T_COMPLEX = 3
# CSR conectado: nrow=10000, ncol=10000, nnz=1000000
# em hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatreqdev(smatrix_t *m) {
#  m->location = 0, LOCDEV = 128
#    m->row_ptr   = 0x221777d0
#    m->col_idx   = 0x2385b430
#    m->values    = 0x230ba220
#    m->idxColMem = (nil)
#    m->extra     = (nil)
# em smatreqdev, ANTES DO fim
#  m->location  = 128, LOCDEV = 128
#  nao coloque NULL.  m->col_idx   = 0x2385b430
#    m->idxColMem = 0x2385b430
#  nao coloque NULL.  m->values = 0x230ba220
#    m->extra  = 0x230ba220
# BD, em ./pyhiperblas/hiperblas_wrapper.c: static PyObject* py_permute_sparse_matrix(PyObject* self, ...
# BD em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-api-impl.c: void * permuteSparseMatrix
#  em computeU + Hiagogo, S->type = 2, C->type = 2, U->type = 2
# BD em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-api-impl.c: void * void computeU, Thread 0 of 1 created!
# Thread 0 of 3 created!, row=0
# Thread 1 of 3 created!, row=3334
# Thread 1 of 3 created!, row=3335
# Thread 1 of 3 created!, row=3336
# Thread 0 of 3 created!, row=1
# Thread 0 of 3 created!, row=2
# Thread 2 of 3 created!, row=6667
# Thread 2 of 3 created!, row=6668
# Thread 2 of 3 created!, row=6669
# BD, ATENCAO !!!  em ./pyhiperblas/hiperblas_wrapper.c: static void py_sparse_matrix_delete
# BD, em py_sparse_matrix_delete, BEFORE CALL smatrix_delete, Liberando smatrix_t em 0x2098c8e0
# BD, ATENCAO, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatrix_delete(smatrix_t *smatrix ), NO FREE! {
# BD, em py_sparse_matrix_delete, AFTER  CALL smatrix_delete, Liberando smatrix_t em 0x2098c8e0
# BD, em final de py_sparse_matrix_delete
# BD, ATENCAO !!!  em ./pyhiperblas/hiperblas_wrapper.c: static void py_sparse_matrix_delete
# BD, em py_sparse_matrix_delete, BEFORE CALL smatrix_delete, Liberando smatrix_t em 0x21d5b840
# BD, ATENCAO, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatrix_delete(smatrix_t *smatrix ), NO FREE! {
# BD, em py_sparse_matrix_delete, AFTER  CALL smatrix_delete, Liberando smatrix_t em 0x21d5b840
# BD, em final de py_sparse_matrix_delete
# BD, ATENCAO !!!  em ./pyhiperblas/hiperblas_wrapper.c: static void py_sparse_matrix_delete
# BD, em py_sparse_matrix_delete, BEFORE CALL smatrix_delete, Liberando smatrix_t em 0x21d5f140
# BD, ATENCAO, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatrix_delete(smatrix_t *smatrix ), NO FREE! {
# BD, em py_sparse_matrix_delete, AFTER  CALL smatrix_delete, Liberando smatrix_t em 0x21d5f140
# BD, em final de py_sparse_matrix_delete

# %% [markdown]
# #### Simulating the QW

# %%
optimal_time = round(np.pi*np.sqrt(N)/2)
initial_state = qw.uniform_state()
aRang=(0, 2*optimal_time)
aRang=(0, 2, 1)
states = qw.simulate(range =aRang, state = initial_state)
# Out:
# BD, em hiperwalk/quantum_walk/quantum_walk.py:    def simulate
# BD, start=0, end=2, step=1
# em quantum_walk.py: def _prepare_engine(self, state, hpc =  cpu
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def send_matrix(M)
# BD, M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, em hiperwalk/quantum_walk/_pyhiperblas_interface.py: def _send_sparse_matrix(M)
# M.dtype= float64 , np.complexfloating= <class 'numpy.complexfloating'>
# BD, is_complex=False
# BD, hiperblas.COMPLEX=3
# BD, hiperblas.FLOAT=2
# BD, em simulate, initial state, state= [ 0.010  0.010  0.010 ...  0.010  0.010  0.010];  BD, em pyhiperblas/hiperblas_wrapper.c: py_sparse_matrix_new( PyObject* self, PyObject* args)
#  call bridge_manager.bridges[bridge_index].smatrix_new(rows, cols, data_type);
# BD, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c, smatrix_new
#  before CALL PyObject* po = PyCapsule_New((void*)a, py_sparse_matrix_new, py_sparse_matrix_delete
# em py_sparse_matrix_new FINAL 0x7fc41d99e4f0
# → Entrou em py_smatrixConnect()
# data_type = 2, T_FLOAT = 2, T_COMPLEX = 3
# CSR conectado: nrow=10000, ncol=10000, nnz=1000000
# em hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatreqdev(smatrix_t *m) {
#  m->location = 0, LOCDEV = 128
#    m->row_ptr   = 0x221777d0
#    m->col_idx   = 0x2385b430
#    m->values    = 0x230ba220
#    m->idxColMem = (nil)
#    m->extra     = (nil)
# em smatreqdev, ANTES DO fim
#  m->location  = 128, LOCDEV = 128
#  nao coloque NULL.  m->col_idx   = 0x2385b430
#    m->idxColMem = 0x2385b430
#  nao coloque NULL.  m->values = 0x230ba220
#    m->extra  = 0x230ba220
# state.l2Norm= 0.9999999999999979
# BD, em def simulate,                     state_index =  1
# BD, em def _simulate_step, step = 1
# BD, em def _simulate_step, HiperBlas, BEFORE CALL multiply_matrix_vector
# BD, em ./hiperwalk/quantum_walk/_pyhiperblas_interface.py, def multiply_matrix_vector( .., is_sparse= True
# BD, em ./hiperwalk/quantum_walk/_pyhiperblas_interface.py, def multiply_matrix_vector, CALL nbl_vec = hiperblas.sparse_matvec_mul, esparsa, para discreto
# BD, em ./pyhiperblas/hiperblas_wrapper.c: static PyObject* py_sparse_matvec_mulBD(PyObject* self, ...
# BD, em hiperblas-core/src/hiperblas_std.c: void ** matvec_mul3BD( bridge_manager_t *mg, int index, void ** i, int * status ) {
# BD, em matvec_mul3BD: v->location= 128, LOCDEV = 128
# BD, em hiperblas-core/src/libhiperblas-cpu-bridge-api-impl.c: void* sparseVecMul(void* v, ...  {
# BD,   em matvec_mul3BD, RETURN (void *) r
# BD, em hiperblas_wraper.c: static PyObject* py_print_vectorT(PyObject* self, PyObject* args)
# BD, em libhiperblas-cpu-bridge-smatrix.c: print_vectorT,
# from v_->extra   [0:9999]: -0.01 0.01 0.01 0.01 0.01 ... 0.01 0.01 0.01 0.01 0.01, L2Norm = 1.000000
# BD, ATENCAO !!!  em ./pyhiperblas/hiperblas_wrapper.c: static void py_sparse_matrix_delete
# BD, em py_sparse_matrix_delete, BEFORE CALL smatrix_delete, Liberando smatrix_t em 0x21d8ad10
# BD, ATENCAO, em /mnt/c/Users/bidu/OneDrive/aLncc/passeiosQuantNov25/hiperwalk/hiperblas-core/src/libhiperblas-cpu-bridge-smatrix.c: void smatrix_delete(smatrix_t *smatrix ), NO FREE! {
# BD, em py_sparse_matrix_delete, AFTER  CALL smatrix_delete, Liberando smatrix_t em 0x21d8ad10
# BD, em final de py_sparse_matrix_delete
# WhileIt  : Tempo decorrido: 0.002296 segundos

# %% [markdown]
# #### Calculating the success probability in a range that includes the optimal time

# %%
list_probs = qw.success_probability(states)

# %% [markdown]
# #### Ploting the success probability as a function of the number of steps

# %%
hpw.plot_success_probability(aRang, list_probs, marker = '.', figsize = (7,3))
